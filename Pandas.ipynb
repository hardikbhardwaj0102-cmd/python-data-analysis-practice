# %%
#hello this is Pandas

# %%
import pandas as pd

# %%
data={"Name":["Hardik","Nishchal","Navik","Sarthya","Kartik"],
     "course":["CSAM","AIML","B.COM","IT","CSE"],
      "roll no.": [352,112,420,234,520],
      "Address": ["Shalimar Garden","Shalimar Garden","DLF","Mayur Vihar","Brij Vihar"]
     }

# %%
 df=pd.DataFrame(data)

# %%
print(df)
# Out:
#        Name course  roll no.          Address
# 0    Hardik   CSAM       352  Shalimar Garden
# 1  Nishchal   AIML       112  Shalimar Garden
# 2     Navik  B.COM       420              DLF
# 3   Sarthya     IT       234      Mayur Vihar
# 4    Kartik    CSE       520       Brij Vihar

# %%
ser=pd.Series(data)

# %%
 print(ser)
# Out:
# Name               [Hardik, Nishchal, Navik, Sarthya, Kartik]
# course                           [CSAM, AIML, B.COM, IT, CSE]
# roll no.                            [352, 112, 420, 234, 520]
# Address     [Shalimar Garden, Shalimar Garden, DLF, Mayur ...
# dtype: object

# %%
pd.Series(data,index=["a","b","c","d","e"])
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# dtype: object

# %%
df.drop("Address",axis=1)
# Out:
#        Name course  roll no.
# 0    Hardik   CSAM       352
# 1  Nishchal   AIML       112
# 2     Navik  B.COM       420
# 3   Sarthya     IT       234
# 4    Kartik    CSE       520

# %%
df.drop(0)
# Out:
#        Name course  roll no.          Address
# 1  Nishchal   AIML       112  Shalimar Garden
# 2     Navik  B.COM       420              DLF
# 3   Sarthya     IT       234      Mayur Vihar
# 4    Kartik    CSE       520       Brij Vihar

# %%
print(df)
# Out:
#        Name course  roll no.          Address
# 0    Hardik   CSAM       352  Shalimar Garden
# 1  Nishchal   AIML       112  Shalimar Garden
# 2     Navik  B.COM       420              DLF
# 3   Sarthya     IT       234      Mayur Vihar
# 4    Kartik    CSE       520       Brij Vihar

# %%
df["Name"]
# Out:
# 0      Hardik
# 1    Nishchal
# 2       Navik
# 3     Sarthya
# 4      Kartik
# Name: Name, dtype: object

# %%
df["Address"]
# Out:
# 0    Shalimar Garden
# 1    Shalimar Garden
# 2                DLF
# 3        Mayur Vihar
# 4         Brij Vihar
# Name: Address, dtype: object

# %%
df["CGPA"] = [9.2,9,9.1,9.2,9.3]

# %%
df
# Out:
#        Name course  roll no.          Address  CGPA
# 0    Hardik   CSAM       352  Shalimar Garden   9.2
# 1  Nishchal   AIML       112  Shalimar Garden   9.0
# 2     Navik  B.COM       420              DLF   9.1
# 3   Sarthya     IT       234      Mayur Vihar   9.2
# 4    Kartik    CSE       520       Brij Vihar   9.3

# %%
df.drop("CGPA")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.drop("CGPA")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.drop("CGPA",axis=1)
# Out:
#        Name course  roll no.          Address
# 0    Hardik   CSAM       352  Shalimar Garden
# 1  Nishchal   AIML       112  Shalimar Garden
# 2     Navik  B.COM       420              DLF
# 3   Sarthya     IT       234      Mayur Vihar
# 4    Kartik    CSE       520       Brij Vihar

# %%
df.drop("Address",axis=1,inplace=True)

# %%
df
# Out:
#        Name course  roll no.  CGPA
# 0    Hardik   CSAM       352   9.2
# 1  Nishchal   AIML       112   9.0
# 2     Navik  B.COM       420   9.1
# 3   Sarthya     IT       234   9.2
# 4    Kartik    CSE       520   9.3

# %%
df[["Name","course","roll no."]]
# Out:
#        Name course  roll no.
# 0    Hardik   CSAM       352
# 1  Nishchal   AIML       112
# 2     Navik  B.COM       420
# 3   Sarthya     IT       234
# 4    Kartik    CSE       520

# %%
df.loc[0]
# Out:
# Name        Hardik
# course        CSAM
# roll no.       352
# CGPA           9.2
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#        Name course  roll no.  CGPA
# 0    Hardik   CSAM       352   9.2
# 1  Nishchal   AIML       112   9.0

# %%
df
# Out:
#        Name course  roll no.  CGPA
# 0    Hardik   CSAM       352   9.2
# 1  Nishchal   AIML       112   9.0
# 2     Navik  B.COM       420   9.1
# 3   Sarthya     IT       234   9.2
# 4    Kartik    CSE       520   9.3

# %%
df.loc[[2,3,4]][["course","roll no.","CGPA"]]
# Out:
#   course  roll no.  CGPA
# 2  B.COM       420   9.1
# 3     IT       234   9.2
# 4    CSE       520   9.3
